# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /Users/esmanur/miniconda3/lib/python3.10/site-packages (3.4.0)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/esmanur/miniconda3/lib/python3.10/site-packages (from pyspark) (0.10.9.7)

# %%
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_replace
from pyspark import SparkConf,SparkContext
from pyspark.sql.functions import split, concat_ws

# %%
data = pd.read_csv("dataset15k.csv")

# %%
data = data.drop("Summary", axis=1)
data = data.drop("img_m", axis=1)
data = data.drop("img_s", axis=1)
data = data.drop("img_l", axis=1)
data = data.drop("Category", axis=1)
data['isbn'] = pd.to_numeric(data['isbn'], errors='coerce',downcast='integer')
data = data.dropna()
data['isbn'] = data['isbn'].astype(int)
data['user_id'] = data["user_id"].astype(str).str[:4]
data['isbn'] = data["isbn"].astype(str).str[:9]
new_df = data.drop("location", axis=1)

# %%
new_df.to_csv("newdataset.csv", index=False)

# %%
d = pd.read_csv("newdataset.csv")

# %%
d.head()
# Out:
#    Unnamed: 0  user_id      age       isbn  rating           book_title  \
# 0           0        2  18.0000  195153448       0  Classical Mythology
# 1           1        8  34.7439    2005018       5         Clara Callan
# 2           2     1140  49.0000    2005018       0         Clara Callan
# 3           4     4138  34.7439    2005018       0         Clara Callan
# 4           5     6754  30.0000    2005018       8         Clara Callan
#
#             book_author  year_of_publication                publisher  \
# 0    Mark P. O. Morford               2002.0  Oxford University Press
# 1  Richard Bruce Wright               2001.0    HarperFlamingo Canada
# 2  Richard Bruce Wright               2001.0    HarperFlamingo Canada
# 3  Richard Bruce Wright               2001.0    HarperFlamingo Canada
# 4  Richard Bruce Wright               2001.0    HarperFlamingo Canada
#
#   Language      city       state country
# 0       en  stockton  california     usa
# 1       en   timmins     ontario  canada
# 2       en    ottawa     ontario  canada
# 3       en   sudbury     ontario  canada
# 4       en   toronto     ontario  canada

# %%
conf = SparkConf().setAppName("191805056_EsmanurDeli")
sc = SparkContext.getOrCreate(conf=conf)

# %%
dataset = sc.textFile("newdataset.csv")

# %%
header = dataset.first()

# %%
data = dataset.filter(lambda line: line != header)

# %%
num_books = data.count()
print("Number of Books: ", num_books)
# Out:
# Number of Books:  13656

# %% [markdown]
# Transform the data by splitting each record into fields.

# %%
book_fields = data.map(lambda lines: lines.split(","))

# %%
book_fields.first()
# Out:
# ['0',
#  '2',
#  '18.0',
#  '195153448',
#  '0',
#  'Classical Mythology',
#  'Mark P. O. Morford',
#  '2002.0',
#  'Oxford University Press',
#  'en',
#  'stockton',
#  'california',
#  'usa']

# %% [markdown]
# Gerekli yerleri nümerik değere çevirme

# %%
isbn = book_fields.map(lambda fields:fields[3])

# %%
isbn_filtered = isbn.map(lambda x: int(x) if x.isdigit() else None).filter(lambda x: x is not None)

# %%
user_id = book_fields.map(lambda fields:fields[1])

# %%
user_id_filtered=user_id.map(lambda x: int(x) if x.isdigit() else None).filter(lambda x: x is not None)

# %%
rating = book_fields.map(lambda fields:fields[4])

# %%
rating_filtered = rating.map(lambda x: int(x) if x.isdigit() else None).filter(lambda x: x is not None)

# %%
user_id_filtered.take(3)
# Out:
# [2, 8, 1140]

# Book: Jane Lindskold, Average Rating: 6.86865234375
# Book:  Elvis, Average Rating: 1.0859375
# Book: Stewart O'Nan, Average Rating: 2.53125
# Book: David Baldacci, Average Rating: 0.5653458367055344
# Book: Mary Lawson, Average Rating: 2.57554721568166
# Book: Olivia Goldsmith, Average Rating: 4.516615516269557
# Book: Helen Fielding, Average Rating: 6.56647701619336
# Book:  The)", Average Rating: 3.0
# Book:  What's the Return Policy?", Average Rating: 2.5
# Book: H. Norman Wright, Average Rating: 0.0
# Book: Schiller, Average Rating: 1.390625
# Book: Raymond Chandler, Average Rating: 10
# Book: Fay Weldon, Average Rating: 0
# Book: Renan Demirkan, Average Rating: 0
# Book: Michael Moore, Average Rating: 5.19921875
# Book: Jerome D. Salinger, Average Rating: 4.0
# Book:  100).", Average Rating: 0
# Book: Joanna Trollope, Average Rating: 10
# Book:  13 3/4 Jahre. cbt. ( Ab 14 J.).", Average Rating: 6
# Book: Milan Kundera, Average Rating: 1.181640625
# Book: Arundhati Roy, Average Rating: 5.890519754902996
# Book: Mary McGarry Morris, Average Rating: 2.5625
# Book: Alice Sebold, Average Rating: 3.5064137153141255

# %% [markdown]
# Build recommendation engine using collaborative filtering.

# %%
from pyspark.mllib. recommendation import ALS # Alternating Least Squares 
from pyspark.mllib.recommendation import Rating
ratings = book_fields.map (lambda x: Rating(int(x[1]), int(x[3]), float(x[4])))

# %%
ratings.take(5)
# Out:
# [Rating(user=2, product=195153448, rating=0.0),
#  Rating(user=8, product=2005018, rating=5.0),
#  Rating(user=1140, product=2005018, rating=0.0),
#  Rating(user=4138, product=2005018, rating=0.0),
#  Rating(user=6754, product=2005018, rating=8.0)]

# %% [markdown]
# Use %70 of dataset for training, rest of them for testing.

# %%
training_data, test_data = ratings.randomSplit([0.7, 0.3])

# %%
training_data.take(10)
# Out:
# [Rating(user=2, product=195153448, rating=0.0),
#  Rating(user=8, product=2005018, rating=5.0),
#  Rating(user=1140, product=2005018, rating=0.0),
#  Rating(user=8552, product=2005018, rating=0.0),
#  Rating(user=9605, product=2005018, rating=0.0),
#  Rating(user=1236, product=2005018, rating=9.0),
#  Rating(user=1774, product=2005018, rating=0.0),
#  Rating(user=2002, product=2005018, rating=8.0),
#  Rating(user=2190, product=2005018, rating=7.0),
#  Rating(user=2633, product=2005018, rating=6.0)]

# %%
training_data = training_data.map(lambda x: (x[0], x[1], int(x[2])))

# %%
training_data.take(10)
# Out:
# [(2, 195153448, 0),
#  (8, 2005018, 5),
#  (1140, 2005018, 0),
#  (8552, 2005018, 0),
#  (9605, 2005018, 0),
#  (1236, 2005018, 9),
#  (1774, 2005018, 0),
#  (2002, 2005018, 8),
#  (2190, 2005018, 7),
#  (2633, 2005018, 6)]

# %% [markdown]
# Use ALS (Alternating Least Squares) for training recommendation model with last 4 digit
# of your student number as a “seed”. Also change the parameters of ALS re-run the
# algorithm for parameters “rank” (10, 50, 200), “iteration” (10, 50, 200) and “lambda”
# (0.01, 0.1).

# %%
from pyspark.mllib.evaluation import RegressionMetrics

seed = 5056
rank_values = [10, 50, 200]
iteration_values = [10, 50, 200]
lambda_values = [0.01, 0.1]

# %%
results = []

# %%
model1 = ALS.train(training_data,rank = 10, 
                   iterations = 10, 
                   lambda_ = 0.01,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model1.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': rank_values[0],
    'Iterations': iteration_values[0],
    'Lambda': lambda_values[0],
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 200:======================>                                 (4 + 6) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 45.839624192966944
# RMSE: 6.7704965986969485
# -------------------------------

# %%
model2 = ALS.train(training_data,rank = 10, 
                   iterations = 50, 
                   lambda_ = 0.01,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model2.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 10,
    'Iterations': 50,
    'Lambda': 0.01,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 924:============================================>           (8 + 2) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 30.579291596554214
# RMSE: 5.529854572821442
# -------------------------------

# %% [markdown]
# model3 = ALS.train(training_data,rank = 10,
#                    iterations = 200, #iterasyondan kaynaklı olabilir
#                    lambda_ = 0.01,
#                    seed = seed)

# %% [markdown]
# test_user_product = test_data.map(lambda x: (x[0], x[1]))
# predictions = model3.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
# rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
# mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
# rmse = mse**0.5
#
# result = {
#     'Rank': 10,
#     'Iterations': 200,
#     'Lambda': 0.01,
#     'MSE': mse,
#     'RMSE': rmse
# }
# results.append(result)
#
# print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("-------------------------------")

# %%
model4 = ALS.train(training_data,rank = 10, 
                   iterations = 10, 
                   lambda_ = 0.1,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model4.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 10,
    'Iterations': 10,
    'Lambda': 0.1,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 1103:=================================================>     (9 + 1) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 24.278863756962583
# RMSE: 4.927358699847473
# -------------------------------

# %%
model5 = ALS.train(training_data,rank = 10, 
                   iterations = 50, 
                   lambda_ = 0.1,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model5.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 10,
    'Iterations': 50,
    'Lambda': 0.1,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 1842:======================================>                (7 + 3) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 22.520058668395368
# RMSE: 4.745530388523012
# -------------------------------
# [Stage 1842:=================================================>     (9 + 1) / 10]

# %% [markdown]
# model6 = ALS.train(training_data,rank = 10,
#                    iterations = 200, #200 olunca sorun çıkarıyor
#                    lambda_ = 0.1,
#                    seed = seed)

# %% [markdown]
# test_user_product = test_data.map(lambda x: (x[0], x[1]))
# predictions = model6.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
# rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
# mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
# rmse = mse**0.5
#
# result = {
#     'Rank': 10,
#     'Iterations': 200,
#     'Lambda': 0.1,
#     'MSE': mse,
#     'RMSE': rmse
# }
# results.append(result)
#
# print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("-------------------------------")

# %%
model7 = ALS.train(training_data,rank = 50, 
                   iterations = 10, 
                   lambda_ = 0.01,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model7.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 50,
    'Iterations': 10,
    'Lambda': 0.01,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 2021:============================================>          (8 + 2) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 20.117511693757628
# RMSE: 4.4852549195957225
# -------------------------------

# %%
model8 = ALS.train(training_data,rank = 50, 
                   iterations = 50, 
                   lambda_ = 0.01,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model8.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 50,
    'Iterations': 50,
    'Lambda': 0.01,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 19.044651944349276
# RMSE: 4.364017867097851
# -------------------------------

# %% [markdown]
# model9 = ALS.train(training_data,rank = 50,
#                    iterations = 200,
#                    lambda_ = 0.01,
#                    seed = seed)

# %% [markdown]
# test_user_product = test_data.map(lambda x: (x[0], x[1]))
# predictions = model9.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
# rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
# mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
# rmse = mse**0.5
#
# result = {
#     'Rank': 50,
#     'Iterations': 200,
#     'Lambda': 0.01,
#     'MSE': mse,
#     'RMSE': rmse
# }
# results.append(result)
#
# print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("-------------------------------")

# %%
model10 = ALS.train(training_data,rank = 50, 
                   iterations = 10, 
                   lambda_ = 0.1,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model10.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 50,
    'Iterations': 10,
    'Lambda': 0.1,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 2939:============================================>          (8 + 2) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 19.512417757654568
# RMSE: 4.417286243572469
# -------------------------------

# %%
model11 = ALS.train(training_data,rank = 50, 
                   iterations = 50, 
                   lambda_ = 0.1,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model11.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 50,
    'Iterations': 50,
    'Lambda': 0.1,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 3678:=================================================>     (9 + 1) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 19.281426710399106
# RMSE: 4.3910621392095
# -------------------------------

# %% [markdown]
# model12 = ALS.train(training_data,rank = 50,
#                    iterations = 200,
#                    lambda_ = 0.01,
#                    seed = seed)

# %% [markdown]
# test_user_product = test_data.map(lambda x: (x[0], x[1]))
# predictions = model12.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
# rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
# mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
# rmse = mse**0.5
#
# result = {
#     'Rank': 50,
#     'Iterations': 200,
#     'Lambda': 0.01,
#     'MSE': mse,
#     'RMSE': rmse
# }
# results.append(result)
#
# print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("-------------------------------")

# %%
model13 = ALS.train(training_data,rank = 200, 
                   iterations = 10, 
                   lambda_ = 0.01,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model13.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 200,
    'Iterations': 10,
    'Lambda': 0.01,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 3857:=================================================>     (9 + 1) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 18.801560218427237
# RMSE: 4.336076592776843
# -------------------------------

# %%
model14 = ALS.train(training_data,rank = 200, 
                   iterations = 50, 
                   lambda_ = 0.01,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model14.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 200,
    'Iterations': 50,
    'Lambda': 0.01,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 4596:============================================>          (8 + 2) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 18.773203386752513
# RMSE: 4.33280548683558
# -------------------------------
# [Stage 4596:=================================================>     (9 + 1) / 10]

# %% [markdown]
# model15 = ALS.train(training_data,rank = 200,
#                    iterations = 200,
#                    lambda_ = 0.01,
#                    seed = seed)

# %% [markdown]
# test_user_product = test_data.map(lambda x: (x[0], x[1]))
# predictions = model15.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
# rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
# mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
# rmse = mse**0.5
#
# result = {
#     'Rank': 200,
#     'Iterations': 200,
#     'Lambda': 0.01,
#     'MSE': mse,
#     'RMSE': rmse
# }
# results.append(result)
#
# print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("-------------------------------")

# %%
model16 = ALS.train(training_data,rank = 200, 
                   iterations = 10, 
                   lambda_ = 0.1,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model16.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 200,
    'Iterations': 10,
    'Lambda': 0.1,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 4775:=================================================>     (9 + 1) / 10]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 19.305439735330168
# RMSE: 4.393795595533566
# -------------------------------

# %%
model17 = ALS.train(training_data,rank = 200, 
                   iterations = 50, 
                   lambda_ = 0.1,
                   seed = seed)

# %%
test_user_product = test_data.map(lambda x: (x[0], x[1]))
predictions = model17.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
rmse = mse**0.5

result = {
    'Rank': 200,
    'Iterations': 50,
    'Lambda': 0.1,
    'MSE': mse,
    'RMSE': rmse
}
results.append(result)

print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
print("MSE:", mse)
print("RMSE:", rmse)
print("-------------------------------")
# Out:
# [Stage 5408:>                                                       (0 + 2) / 2]
# Model Parameters: Rank=0.01, Iterations=10, Lambda=0.01
# MSE: 19.274294182293882
# RMSE: 4.3902498997544415
# -------------------------------

# %% [markdown]
# model18 = ALS.train(training_data,rank = 200,
#                    iterations = 200,
#                    lambda_ = 0.1,
#                    seed = seed)

# %% [markdown]
# test_user_product = test_data.map(lambda x: (x[0], x[1]))
# predictions = model18.predictAll(test_user_product).map(lambda x: ((x[0], x[1]), x[2]))
# rates_and_preds = test_data.map(lambda x: ((x[0], x[1]), x[2])).join(predictions)
# mse = rates_and_preds.map(lambda x: (x[1][0] - x[1][1])**2).mean()
# rmse = mse**0.5
#
# result = {
#     'Rank': 200,
#     'Iterations': 200,
#     'Lambda': 0.1,
#     'MSE': mse,
#     'RMSE': rmse
# }
# results.append(result)
#
# print("Model Parameters: Rank={}, Iterations={}, Lambda={}".format(lambda_values[0], iteration_values[0], lambda_values[0]))
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("-------------------------------")

# %% [markdown]
# ALS ile tahminde bulunup (predict) bunu yan yana gelecek şekilde orijinal (gerçek değerler ile) değerlendirmeler ile karşılaştırması olmalı. En iyi model ile bunu yapıyoruz

# %%
test_data
# Out:
# [Rating(user=4138, product=2005018, rating=0.0),
#  Rating(user=6754, product=2005018, rating=8.0),
#  Rating(user=2109, product=2005018, rating=9.0),
#  Rating(user=8, product=60973129, rating=0.0),
#  Rating(user=1109, product=374157065, rating=10.0),
#  Rating(user=1926, product=374157065, rating=8.0),
#  Rating(user=2952, product=399135782, rating=9.0),
#  Rating(user=3683, product=399135782, rating=0.0),
#  Rating(user=1132, product=399135782, rating=0.0),
#  Rating(user=1135, product=399135782, rating=0.0),
#  Rating(user=1534, product=399135782, rating=0.0),
#  Rating(user=1802, product=399135782, rating=0.0),
#  Rating(user=1885, product=399135782, rating=0.0),
#  Rating(user=1980, product=399135782, rating=7.0),
#  Rating(user=2124, product=399135782, rating=8.0),
#  Rating(user=2422, product=399135782, rating=0.0),
#  Rating(user=2522, product=399135782, rating=0.0),
#  Rating(user=2529, product=399135782, rating=8.0),
#  Rating(user=5261, product=425176428, rating=8.0),
#  Rating(user=9849, product=771074670, rating=0.0),
#  Rating(user=1892, product=771074670, rating=6.0),
#  Rating(user=2230, product=771074670, rating=0.0),
#  Rating(user=8, product=155874621, rating=0.0),
#  Rating(user=2562, product=155874621, rating=0.0),
#  Rating(user=1768, product=157566393, rating=0.0),
#  Rating(user=2139, product=157566393, rating=0.0),
#  Rating(user=388, product=440234743, rating=0.0),
#  Rating(user=7346, product=440234743, rating=9.0),
#  Rating(user=1268, product=440234743, rating=10.0),
#  Rating(user=1355, product=440234743, rating=8.0),
#  Rating(user=1358, product=440234743, rating=0.0),
#  Rating(user=1452, product=440234743, rating=0.0),
#  Rating(user=1679, product=440234743, rating=0.0),
#  Rating(user=2046, product=440234743, rating=0.0),
#  Rating(user=2078, product=440234743, rating=0.0),
#  Rating(user=2080, product=440234743, rating=8.0),
#  Rating(user=2091, product=440234743, rating=7.0),
#  Rating(user=3048, product=440234743, rating=0.0),
#  Rating(user=3155, product=440234743, rating=0.0),
#  Rating(user=3251, product=440234743, rating=0.0),
#  Rating(user=4088, product=440234743, rating=0.0),
#  Rating(user=4558, product=440234743, rating=7.0),
#  Rating(user=5488, product=440234743, rating=8.0),
#  Rating(user=5710, product=440234743, rating=0.0),
#  Rating(user=5903, product=440234743, rating=0.0),
#  Rating(user=6056, product=440234743, rating=0.0),
#  Rating(user=6453, product=440234743, rating=7.0),
#  Rating(user=6460, product=440234743, rating=0.0),
#  Rating(user=6923, product=440234743, rating=0.0),
#  Rating(user=7020, product=440234743, rating=0.0),
#  Rating(user=7066, product=440234743, rating=7.0),
#  Rating(user=7297, product=440234743, rating=7.0),
#  Rating(user=7635, product=440234743, rating=0.0),
#  Rating(user=7883, product=440234743, rating=0.0),
#  Rating(user=7918, product=440234743, rating=0.0),
#  Rating(user=8108, product=440234743, rating=0.0),
#  Rating(user=8129, product=440234743, rating=0.0),
#  Rating(user=8289, product=440234743, rating=0.0),
#  Rating(user=8630, product=440234743, rating=0.0),
#  Rating(user=8792, product=440234743, rating=0.0),
#  Rating(user=9032, product=440234743, rating=0.0),
#  Rating(user=9377, product=440234743, rating=9.0),
#  Rating(user=9413, product=440234743, rating=8.0),
#  Rating(user=9846, product=440234743, rating=0.0),
#  Rating(user=1012, product=440234743, rating=7.0),
#  Rating(user=1033, product=440234743, rating=0.0),
#  Rating(user=1056, product=440234743, rating=0.0),
#  Rating(user=1062, product=440234743, rating=0.0),
#  Rating(user=1072, product=440234743, rating=0.0),
#  Rating(user=1077, product=440234743, rating=9.0),
#  Rating(user=1104, product=440234743, rating=0.0),
#  Rating(user=1120, product=440234743, rating=4.0),
#  Rating(user=1150, product=440234743, rating=0.0),
#  Rating(user=1193, product=440234743, rating=0.0),
#  Rating(user=1207, product=440234743, rating=8.0),
#  Rating(user=1222, product=440234743, rating=7.0),
#  Rating(user=1307, product=440234743, rating=8.0),
#  Rating(user=1318, product=440234743, rating=0.0),
#  Rating(user=1337, product=440234743, rating=0.0),
#  Rating(user=1351, product=440234743, rating=0.0),
#  Rating(user=1358, product=440234743, rating=0.0),
#  Rating(user=1408, product=440234743, rating=0.0),
#  Rating(user=1420, product=440234743, rating=0.0),
#  Rating(user=1432, product=440234743, rating=0.0),
#  Rating(user=1442, product=440234743, rating=5.0),
#  Rating(user=1444, product=440234743, rating=0.0),
#  Rating(user=1456, product=440234743, rating=0.0),
#  Rating(user=1462, product=440234743, rating=8.0),
#  Rating(user=1510, product=440234743, rating=9.0),
#  Rating(user=1510, product=440234743, rating=10.0),
#  Rating(user=1526, product=440234743, rating=0.0),
#  Rating(user=1595, product=440234743, rating=8.0),
#  Rating(user=1607, product=440234743, rating=7.0),
#  Rating(user=1618, product=440234743, rating=5.0),
#  Rating(user=1636, product=440234743, rating=6.0),
#  Rating(user=1643, product=440234743, rating=0.0),
#  Rating(user=1658, product=440234743, rating=7.0),
#  Rating(user=1670, product=440234743, rating=9.0),
#  Rating(user=1694, product=440234743, rating=0.0),
#  Rating(user=1705, product=440234743, rating=0.0),
#  Rating(user=1746, product=440234743, rating=0.0),
#  Rating(user=1751, product=440234743, rating=0.0),
#  Rating(user=1764, product=440234743, rating=0.0),
#  Rating(user=1768, product=440234743, rating=0.0),
#  Rating(user=1781, product=440234743, rating=0.0),
#  Rating(user=1790, product=440234743, rating=0.0),
#  Rating(user=1879, product=440234743, rating=6.0),
#  Rating(user=1907, product=440234743, rating=0.0),
#  Rating(user=1923, product=440234743, rating=0.0),
#  Rating(user=1938, product=440234743, rating=9.0),
#  Rating(user=1953, product=440234743, rating=7.0),
#  Rating(user=1984, product=440234743, rating=0.0),
#  Rating(user=1987, product=440234743, rating=0.0),
#  Rating(user=2004, product=440234743, rating=8.0),
#  Rating(user=2026, product=440234743, rating=0.0),
#  Rating(user=2064, product=440234743, rating=4.0),
#  Rating(user=2072, product=440234743, rating=0.0),
#  Rating(user=2078, product=440234743, rating=7.0),
#  Rating(user=2128, product=440234743, rating=0.0),
#  Rating(user=2137, product=440234743, rating=0.0),
#  Rating(user=2147, product=440234743, rating=9.0),
#  Rating(user=2166, product=440234743, rating=8.0),
#  Rating(user=2181, product=440234743, rating=8.0),
#  Rating(user=2244, product=440234743, rating=0.0),
#  Rating(user=2247, product=440234743, rating=0.0),
#  Rating(user=2257, product=440234743, rating=0.0),
#  Rating(user=2258, product=440234743, rating=0.0),
#  Rating(user=2266, product=440234743, rating=0.0),
#  Rating(user=2273, product=440234743, rating=7.0),
#  Rating(user=2281, product=440234743, rating=0.0),
#  Rating(user=2296, product=440234743, rating=0.0),
#  Rating(user=2337, product=440234743, rating=7.0),
#  Rating(user=2346, product=440234743, rating=0.0),
#  Rating(user=2358, product=440234743, rating=0.0),
#  Rating(user=2400, product=440234743, rating=0.0),
#  Rating(user=2401, product=440234743, rating=0.0),
#  Rating(user=2409, product=440234743, rating=10.0),
#  Rating(user=2413, product=440234743, rating=0.0),
#  Rating(user=2428, product=440234743, rating=0.0),
#  Rating(user=2459, product=440234743, rating=0.0),
#  Rating(user=2499, product=440234743, rating=0.0),
#  Rating(user=2501, product=440234743, rating=9.0),
#  Rating(user=2501, product=440234743, rating=0.0),
#  Rating(user=2511, product=440234743, rating=9.0),
#  Rating(user=2516, product=440234743, rating=0.0),
#  Rating(user=2531, product=440234743, rating=0.0),
#  Rating(user=2549, product=440234743, rating=0.0),
#  Rating(user=2557, product=440234743, rating=0.0),
#  Rating(user=2569, product=440234743, rating=8.0),
#  Rating(user=2588, product=440234743, rating=5.0),
#  Rating(user=2597, product=440234743, rating=0.0),
#  Rating(user=2618, product=440234743, rating=0.0),
#  Rating(user=2638, product=440234743, rating=0.0),
#  Rating(user=2653, product=440234743, rating=0.0),
#  Rating(user=2662, product=440234743, rating=10.0),
#  Rating(user=2712, product=440234743, rating=0.0),
#  Rating(user=2739, product=440234743, rating=9.0),
#  Rating(user=2743, product=440234743, rating=0.0),
#  Rating(user=2766, product=440234743, rating=6.0),
#  Rating(user=2781, product=440234743, rating=0.0),
#  Rating(user=4781, product=452264464, rating=0.0),
#  Rating(user=2805, product=452264464, rating=9.0),
#  Rating(user=3486, product=452264464, rating=0.0),
#  Rating(user=4033, product=452264464, rating=8.0),
#  Rating(user=4998, product=452264464, rating=2.0),
#  Rating(user=5283, product=452264464, rating=1.0),
#  Rating(user=6060, product=452264464, rating=0.0),
#  Rating(user=6395, product=452264464, rating=9.0),
#  Rating(user=8240, product=452264464, rating=0.0),
#  Rating(user=8774, product=452264464, rating=0.0),
#  Rating(user=9183, product=452264464, rating=0.0),
#  Rating(user=9369, product=452264464, rating=0.0),
#  Rating(user=9539, product=452264464, rating=5.0),
#  Rating(user=9994, product=452264464, rating=8.0),
#  Rating(user=1023, product=452264464, rating=8.0),
#  Rating(user=1047, product=452264464, rating=8.0),
#  Rating(user=1146, product=452264464, rating=0.0),
#  Rating(user=1151, product=452264464, rating=0.0),
#  Rating(user=1242, product=452264464, rating=10.0),
#  Rating(user=1248, product=452264464, rating=0.0),
#  Rating(user=1329, product=452264464, rating=9.0),
#  Rating(user=1439, product=452264464, rating=0.0),
#  Rating(user=1509, product=452264464, rating=0.0),
#  Rating(user=1509, product=452264464, rating=0.0),
#  Rating(user=1530, product=452264464, rating=0.0),
#  Rating(user=1536, product=452264464, rating=0.0),
#  Rating(user=1577, product=452264464, rating=5.0),
#  Rating(user=1600, product=452264464, rating=0.0),
#  Rating(user=1653, product=452264464, rating=5.0),
#  Rating(user=2048, product=452264464, rating=0.0),
#  Rating(user=2079, product=452264464, rating=0.0),
#  Rating(user=2128, product=452264464, rating=0.0),
#  Rating(user=2270, product=452264464, rating=0.0),
#  Rating(user=2272, product=452264464, rating=0.0),
#  Rating(user=2302, product=452264464, rating=0.0),
#  Rating(user=2305, product=452264464, rating=0.0),
#  Rating(user=2312, product=452264464, rating=0.0),
#  Rating(user=2381, product=452264464, rating=0.0),
#  Rating(user=2441, product=452264464, rating=0.0),
#  Rating(user=2507, product=452264464, rating=8.0),
#  Rating(user=2508, product=452264464, rating=9.0),
#  Rating(user=2526, product=452264464, rating=8.0),
#  Rating(user=2645, product=452264464, rating=8.0),
#  Rating(user=2695, product=452264464, rating=0.0),
#  Rating(user=2711, product=452264464, rating=5.0),
#  Rating(user=2740, product=452264464, rating=0.0),
#  Rating(user=9, product=609804618, rating=0.0),
#  Rating(user=2062, product=609804618, rating=10.0),
#  Rating(user=1838, product=184172152, rating=0.0),
#  Rating(user=8090, product=184172152, rating=0.0),
#  Rating(user=1248, product=184172152, rating=0.0),
#  Rating(user=1266, product=184172152, rating=0.0),
#  Rating(user=1374, product=184172152, rating=0.0),
#  Rating(user=1521, product=184172152, rating=0.0),
#  Rating(user=1829, product=184172152, rating=0.0),
#  Rating(user=2483, product=184172152, rating=0.0),
#  Rating(user=6463, product=187938449, rating=0.0),
#  Rating(user=14, product=439095026, rating=5.0),
#  Rating(user=1264, product=439095026, rating=0.0),
#  Rating(user=1640, product=439095026, rating=8.0),
#  Rating(user=242, product=971880107, rating=0.0),
#  Rating(user=626, product=971880107, rating=0.0),
#  Rating(user=899, product=971880107, rating=2.0),
#  Rating(user=1025, product=971880107, rating=0.0),
#  Rating(user=1733, product=971880107, rating=1.0),
#  Rating(user=1863, product=971880107, rating=0.0),
#  Rating(user=1903, product=971880107, rating=0.0),
#  Rating(user=2411, product=971880107, rating=3.0),
#  Rating(user=3556, product=971880107, rating=0.0),
#  Rating(user=4285, product=971880107, rating=0.0),
#  Rating(user=5506, product=971880107, rating=0.0),
#  Rating(user=5543, product=971880107, rating=0.0),
#  Rating(user=6431, product=971880107, rating=4.0),
#  Rating(user=6507, product=971880107, rating=0.0),
#  Rating(user=6543, product=971880107, rating=0.0),
#  Rating(user=7158, product=971880107, rating=0.0),
#  Rating(user=7286, product=971880107, rating=0.0),
#  Rating(user=7515, product=971880107, rating=0.0),
#  Rating(user=7864, product=971880107, rating=0.0),
#  Rating(user=8361, product=971880107, rating=2.0),
#  Rating(user=8453, product=971880107, rating=3.0),
#  Rating(user=8529, product=971880107, rating=0.0),
#  Rating(user=9080, product=971880107, rating=0.0),
#  Rating(user=9642, product=971880107, rating=0.0),
#  Rating(user=1033, product=971880107, rating=0.0),
#  Rating(user=1059, product=971880107, rating=0.0),
#  Rating(user=1122, product=971880107, rating=1.0),
#  Rating(user=1194, product=971880107, rating=0.0),
#  Rating(user=1305, product=971880107, rating=0.0),
#  Rating(user=1347, product=971880107, rating=4.0),
#  Rating(user=1404, product=971880107, rating=1.0),
#  Rating(user=1420, product=971880107, rating=0.0),
#  Rating(user=1421, product=971880107, rating=0.0),
#  Rating(user=1433, product=971880107, rating=0.0),
#  Rating(user=1446, product=971880107, rating=8.0),
#  Rating(user=1615, product=971880107, rating=0.0),
#  Rating(user=1626, product=971880107, rating=5.0),
#  Rating(user=1650, product=971880107, rating=0.0),
#  Rating(user=1663, product=971880107, rating=0.0),
#  Rating(user=1678, product=971880107, rating=0.0),
#  Rating(user=1694, product=971880107, rating=0.0),
#  Rating(user=1720, product=971880107, rating=0.0),
#  Rating(user=1789, product=971880107, rating=0.0),
#  Rating(user=1795, product=971880107, rating=0.0),
#  Rating(user=1819, product=971880107, rating=0.0),
#  Rating(user=1908, product=971880107, rating=0.0),
#  Rating(user=1911, product=971880107, rating=0.0),
#  Rating(user=1997, product=971880107, rating=0.0),
#  Rating(user=2020, product=971880107, rating=0.0),
#  Rating(user=2091, product=971880107, rating=0.0),
#  Rating(user=2098, product=971880107, rating=0.0),
#  Rating(user=2125, product=971880107, rating=0.0),
#  Rating(user=2140, product=971880107, rating=3.0),
#  Rating(user=2186, product=971880107, rating=0.0),
#  Rating(user=2208, product=971880107, rating=0.0),
#  Rating(user=2212, product=971880107, rating=0.0),
#  Rating(user=2302, product=971880107, rating=10.0),
#  Rating(user=2357, product=971880107, rating=0.0),
#  Rating(user=2418, product=971880107, rating=1.0),
#  Rating(user=2430, product=971880107, rating=0.0),
#  Rating(user=2466, product=971880107, rating=8.0),
#  Rating(user=2492, product=971880107, rating=0.0),
#  Rating(user=2539, product=971880107, rating=0.0),
#  Rating(user=2589, product=971880107, rating=8.0),
#  Rating(user=2652, product=971880107, rating=0.0),
#  Rating(user=2681, product=971880107, rating=0.0),
#  Rating(user=2746, product=971880107, rating=0.0),
#  Rating(user=2765, product=971880107, rating=0.0),
#  Rating(user=2781, product=971880107, rating=0.0),
#  Rating(user=2826, product=971880107, rating=8.0),
#  Rating(user=2849, product=971880107, rating=0.0),
#  Rating(user=2863, product=971880107, rating=0.0),
#  Rating(user=2864, product=971880107, rating=0.0),
#  Rating(user=3034, product=971880107, rating=0.0),
#  Rating(user=3053, product=971880107, rating=0.0),
#  Rating(user=3146, product=971880107, rating=0.0),
#  Rating(user=3244, product=971880107, rating=0.0),
#  Rating(user=3248, product=971880107, rating=0.0),
#  Rating(user=3281, product=971880107, rating=0.0),
#  Rating(user=3348, product=971880107, rating=0.0),
#  Rating(user=3430, product=971880107, rating=0.0),
#  Rating(user=3551, product=971880107, rating=8.0),
#  Rating(user=3604, product=971880107, rating=3.0),
#  Rating(user=3660, product=971880107, rating=0.0),
#  Rating(user=3670, product=971880107, rating=0.0),
#  Rating(user=3690, product=971880107, rating=0.0),
#  Rating(user=3707, product=971880107, rating=8.0),
#  Rating(user=3729, product=971880107, rating=3.0),
#  Rating(user=3754, product=971880107, rating=0.0),
#  Rating(user=3769, product=971880107, rating=0.0),
#  Rating(user=3821, product=971880107, rating=0.0),
#  Rating(user=3822, product=971880107, rating=0.0),
#  Rating(user=3893, product=971880107, rating=0.0),
#  Rating(user=3965, product=971880107, rating=0.0),
#  Rating(user=3965, product=971880107, rating=0.0),
#  Rating(user=4075, product=971880107, rating=0.0),
#  Rating(user=4095, product=971880107, rating=0.0),
#  Rating(user=4113, product=971880107, rating=6.0),
#  Rating(user=4118, product=971880107, rating=0.0),
#  Rating(user=4296, product=971880107, rating=2.0),
#  Rating(user=4305, product=971880107, rating=0.0),
#  Rating(user=4492, product=971880107, rating=0.0),
#  Rating(user=4500, product=971880107, rating=0.0),
#  Rating(user=4503, product=971880107, rating=0.0),
#  Rating(user=4626, product=971880107, rating=0.0),
#  Rating(user=4639, product=971880107, rating=4.0),
#  Rating(user=4712, product=971880107, rating=0.0),
#  Rating(user=4763, product=971880107, rating=0.0),
#  Rating(user=4785, product=971880107, rating=0.0),
#  Rating(user=4804, product=971880107, rating=0.0),
#  Rating(user=4946, product=971880107, rating=0.0),
#  Rating(user=4963, product=971880107, rating=4.0),
#  Rating(user=4995, product=971880107, rating=1.0),
#  Rating(user=5016, product=971880107, rating=7.0),
#  Rating(user=5171, product=971880107, rating=0.0),
#  Rating(user=5180, product=971880107, rating=1.0),
#  Rating(user=5194, product=971880107, rating=0.0),
#  Rating(user=5206, product=971880107, rating=0.0),
#  Rating(user=5300, product=971880107, rating=0.0),
#  Rating(user=5304, product=971880107, rating=1.0),
#  Rating(user=5314, product=971880107, rating=0.0),
#  Rating(user=5347, product=971880107, rating=0.0),
#  Rating(user=5362, product=971880107, rating=0.0),
#  Rating(user=5368, product=971880107, rating=0.0),
#  Rating(user=5372, product=971880107, rating=0.0),
#  Rating(user=5439, product=971880107, rating=0.0),
#  Rating(user=5445, product=971880107, rating=1.0),
#  Rating(user=5464, product=971880107, rating=3.0),
#  Rating(user=5485, product=971880107, rating=0.0),
#  Rating(user=5589, product=971880107, rating=1.0),
#  Rating(user=5600, product=971880107, rating=0.0),
#  Rating(user=5685, product=971880107, rating=0.0),
#  Rating(user=5700, product=971880107, rating=0.0),
#  Rating(user=5703, product=971880107, rating=5.0),
#  Rating(user=5795, product=971880107, rating=0.0),
#  Rating(user=5829, product=971880107, rating=6.0),
#  Rating(user=5979, product=971880107, rating=0.0),
#  Rating(user=5991, product=971880107, rating=0.0),
#  Rating(user=6031, product=971880107, rating=0.0),
#  Rating(user=6063, product=971880107, rating=8.0),
#  Rating(user=6289, product=971880107, rating=0.0),
#  Rating(user=6295, product=971880107, rating=0.0),
#  Rating(user=6329, product=971880107, rating=0.0),
#  Rating(user=6397, product=971880107, rating=8.0),
#  Rating(user=6437, product=971880107, rating=0.0),
#  Rating(user=6444, product=971880107, rating=0.0),
#  Rating(user=6514, product=971880107, rating=5.0),
#  Rating(user=6532, product=971880107, rating=0.0),
#  Rating(user=6546, product=971880107, rating=5.0),
#  Rating(user=6599, product=971880107, rating=0.0),
#  Rating(user=6644, product=971880107, rating=0.0),
#  Rating(user=6674, product=971880107, rating=0.0),
#  Rating(user=6741, product=971880107, rating=3.0),
#  Rating(user=6751, product=971880107, rating=3.0),
#  Rating(user=6763, product=971880107, rating=7.0),
#  Rating(user=6784, product=971880107, rating=0.0),
#  Rating(user=6825, product=971880107, rating=0.0),
#  Rating(user=6972, product=971880107, rating=0.0),
#  Rating(user=6997, product=971880107, rating=0.0),
#  Rating(user=7022, product=971880107, rating=5.0),
#  Rating(user=7057, product=971880107, rating=0.0),
#  Rating(user=7123, product=971880107, rating=0.0),
#  Rating(user=7144, product=971880107, rating=0.0),
#  Rating(user=7211, product=971880107, rating=0.0),
#  Rating(user=7221, product=971880107, rating=0.0),
#  Rating(user=7228, product=971880107, rating=0.0),
#  Rating(user=7242, product=971880107, rating=1.0),
#  Rating(user=7322, product=971880107, rating=0.0),
#  Rating(user=7344, product=971880107, rating=0.0),
#  Rating(user=7349, product=971880107, rating=0.0),
#  Rating(user=7351, product=971880107, rating=0.0),
#  Rating(user=7368, product=971880107, rating=0.0),
#  Rating(user=7392, product=971880107, rating=0.0),
#  Rating(user=7394, product=971880107, rating=8.0),
#  Rating(user=7412, product=971880107, rating=0.0),
#  Rating(user=7418, product=971880107, rating=0.0),
#  Rating(user=7491, product=971880107, rating=6.0),
#  Rating(user=7528, product=971880107, rating=0.0),
#  Rating(user=7533, product=971880107, rating=0.0),
#  Rating(user=7549, product=971880107, rating=0.0),
#  Rating(user=7584, product=971880107, rating=1.0),
#  Rating(user=7615, product=971880107, rating=0.0),
#  Rating(user=7635, product=971880107, rating=0.0),
#  Rating(user=7718, product=971880107, rating=0.0),
#  Rating(user=7918, product=971880107, rating=0.0),
#  Rating(user=7994, product=971880107, rating=0.0),
#  Rating(user=8055, product=971880107, rating=6.0),
#  Rating(user=8104, product=971880107, rating=0.0),
#  Rating(user=8106, product=971880107, rating=2.0),
#  Rating(user=8110, product=971880107, rating=0.0),
#  Rating(user=8132, product=971880107, rating=0.0),
#  Rating(user=8160, product=971880107, rating=0.0),
#  Rating(user=8163, product=971880107, rating=8.0),
#  Rating(user=8186, product=971880107, rating=0.0),
#  Rating(user=8283, product=971880107, rating=7.0),
#  Rating(user=8315, product=971880107, rating=0.0),
#  Rating(user=8340, product=971880107, rating=0.0),
#  Rating(user=8357, product=971880107, rating=8.0),
#  Rating(user=8402, product=971880107, rating=0.0),
#  Rating(user=8488, product=971880107, rating=0.0),
#  Rating(user=8504, product=971880107, rating=0.0),
#  Rating(user=8548, product=971880107, rating=0.0),
#  Rating(user=8576, product=971880107, rating=0.0),
#  Rating(user=8599, product=971880107, rating=0.0),
#  Rating(user=8654, product=971880107, rating=0.0),
#  Rating(user=8700, product=971880107, rating=0.0),
#  Rating(user=8702, product=971880107, rating=0.0),
#  Rating(user=8772, product=971880107, rating=0.0),
#  Rating(user=8779, product=971880107, rating=0.0),
#  Rating(user=8807, product=971880107, rating=0.0),
#  Rating(user=8828, product=971880107, rating=0.0),
#  Rating(user=8869, product=971880107, rating=4.0),
#  Rating(user=8872, product=971880107, rating=0.0),
#  Rating(user=8920, product=971880107, rating=0.0),
#  Rating(user=8986, product=971880107, rating=3.0),
#  Rating(user=9013, product=971880107, rating=0.0),
#  Rating(user=9023, product=971880107, rating=0.0),
#  Rating(user=9028, product=971880107, rating=0.0),
#  Rating(user=9069, product=971880107, rating=0.0),
#  Rating(user=9104, product=971880107, rating=1.0),
#  Rating(user=9144, product=971880107, rating=0.0),
#  Rating(user=9155, product=971880107, rating=2.0),
#  Rating(user=9169, product=971880107, rating=0.0),
#  Rating(user=9193, product=971880107, rating=0.0),
#  Rating(user=9272, product=971880107, rating=1.0),
#  Rating(user=9308, product=971880107, rating=0.0),
#  Rating(user=9327, product=971880107, rating=3.0),
#  Rating(user=9412, product=971880107, rating=0.0),
#  Rating(user=9485, product=971880107, rating=6.0),
#  Rating(user=9486, product=971880107, rating=0.0),
#  Rating(user=9526, product=971880107, rating=0.0),
#  Rating(user=9544, product=971880107, rating=0.0),
#  Rating(user=9578, product=971880107, rating=0.0),
#  Rating(user=9590, product=971880107, rating=0.0),
#  Rating(user=9652, product=971880107, rating=0.0),
#  Rating(user=9679, product=971880107, rating=0.0),
#  Rating(user=9780, product=971880107, rating=0.0),
#  Rating(user=9829, product=971880107, rating=0.0),
#  Rating(user=9845, product=971880107, rating=0.0),
#  Rating(user=9865, product=971880107, rating=2.0),
#  Rating(user=9902, product=971880107, rating=2.0),
#  Rating(user=9956, product=971880107, rating=0.0),
#  Rating(user=9962, product=971880107, rating=0.0),
#  Rating(user=9994, product=971880107, rating=3.0),
#  Rating(user=1002, product=971880107, rating=0.0),
#  Rating(user=1004, product=971880107, rating=1.0),
#  Rating(user=1006, product=971880107, rating=8.0),
#  Rating(user=1011, product=971880107, rating=0.0),
#  Rating(user=1013, product=971880107, rating=0.0),
#  Rating(user=1019, product=971880107, rating=0.0),
#  Rating(user=1020, product=971880107, rating=0.0),
#  Rating(user=1033, product=971880107, rating=0.0),
#  Rating(user=1035, product=971880107, rating=0.0),
#  Rating(user=1042, product=971880107, rating=6.0),
#  Rating(user=1056, product=971880107, rating=0.0),
#  Rating(user=1062, product=971880107, rating=0.0),
#  Rating(user=1067, product=971880107, rating=0.0),
#  Rating(user=1068, product=971880107, rating=0.0),
#  Rating(user=1079, product=971880107, rating=0.0),
#  Rating(user=1086, product=971880107, rating=0.0),
#  Rating(user=1087, product=971880107, rating=0.0),
#  Rating(user=1088, product=971880107, rating=2.0),
#  Rating(user=1093, product=971880107, rating=4.0),
#  Rating(user=1094, product=971880107, rating=0.0),
#  Rating(user=1094, product=971880107, rating=0.0),
#  Rating(user=1099, product=971880107, rating=0.0),
#  Rating(user=1100, product=971880107, rating=0.0),
#  Rating(user=1101, product=971880107, rating=0.0),
#  Rating(user=1103, product=971880107, rating=0.0),
#  Rating(user=1114, product=971880107, rating=6.0),
#  Rating(user=1133, product=971880107, rating=0.0),
#  Rating(user=1142, product=971880107, rating=5.0),
#  Rating(user=1150, product=971880107, rating=0.0),
#  Rating(user=1150, product=971880107, rating=0.0),
#  Rating(user=1151, product=971880107, rating=0.0),
#  Rating(user=1151, product=971880107, rating=0.0),
#  Rating(user=1156, product=971880107, rating=0.0),
#  Rating(user=1157, product=971880107, rating=1.0),
#  Rating(user=1162, product=971880107, rating=0.0),
#  Rating(user=1163, product=971880107, rating=0.0),
#  Rating(user=1167, product=971880107, rating=0.0),
#  Rating(user=1169, product=971880107, rating=0.0),
#  Rating(user=1170, product=971880107, rating=0.0),
#  Rating(user=1175, product=971880107, rating=5.0),
#  Rating(user=1186, product=971880107, rating=0.0),
#  Rating(user=1205, product=971880107, rating=0.0),
#  Rating(user=1212, product=971880107, rating=0.0),
#  Rating(user=1213, product=971880107, rating=0.0),
#  Rating(user=1219, product=971880107, rating=0.0),
#  Rating(user=1220, product=971880107, rating=0.0),
#  Rating(user=1225, product=971880107, rating=0.0),
#  Rating(user=1227, product=971880107, rating=0.0),
#  Rating(user=1228, product=971880107, rating=0.0),
#  Rating(user=1229, product=971880107, rating=0.0),
#  Rating(user=1238, product=971880107, rating=5.0),
#  Rating(user=1240, product=971880107, rating=0.0),
#  Rating(user=1245, product=971880107, rating=0.0),
#  Rating(user=1248, product=971880107, rating=6.0),
#  Rating(user=1252, product=971880107, rating=0.0),
#  Rating(user=1258, product=971880107, rating=4.0),
#  Rating(user=1266, product=971880107, rating=1.0),
#  Rating(user=1267, product=971880107, rating=0.0),
#  Rating(user=1268, product=971880107, rating=4.0),
#  Rating(user=1271, product=971880107, rating=0.0),
#  Rating(user=1276, product=971880107, rating=0.0),
#  Rating(user=1280, product=971880107, rating=0.0),
#  Rating(user=1283, product=971880107, rating=0.0),
#  Rating(user=1285, product=971880107, rating=0.0),
#  Rating(user=1287, product=971880107, rating=0.0),
#  Rating(user=1296, product=971880107, rating=0.0),
#  Rating(user=1315, product=971880107, rating=9.0),
#  Rating(user=1316, product=971880107, rating=0.0),
#  Rating(user=1318, product=971880107, rating=0.0),
#  Rating(user=1322, product=971880107, rating=0.0),
#  Rating(user=1323, product=971880107, rating=5.0),
#  Rating(user=1325, product=971880107, rating=0.0),
#  Rating(user=1326, product=971880107, rating=0.0),
#  Rating(user=1328, product=971880107, rating=0.0),
#  Rating(user=1333, product=971880107, rating=0.0),
#  Rating(user=1333, product=971880107, rating=0.0),
#  Rating(user=1340, product=971880107, rating=0.0),
#  Rating(user=1348, product=971880107, rating=0.0),
#  Rating(user=1356, product=971880107, rating=0.0),
#  Rating(user=1358, product=971880107, rating=0.0),
#  Rating(user=1359, product=971880107, rating=9.0),
#  Rating(user=1362, product=971880107, rating=0.0),
#  Rating(user=1363, product=971880107, rating=0.0),
#  Rating(user=1363, product=971880107, rating=0.0),
#  Rating(user=1364, product=971880107, rating=0.0),
#  Rating(user=1367, product=971880107, rating=7.0),
#  Rating(user=1369, product=971880107, rating=0.0),
#  Rating(user=1369, product=971880107, rating=0.0),
#  Rating(user=1383, product=971880107, rating=0.0),
#  Rating(user=1396, product=971880107, rating=0.0),
#  Rating(user=1400, product=971880107, rating=0.0),
#  Rating(user=1400, product=971880107, rating=0.0),
#  Rating(user=1401, product=971880107, rating=0.0),
#  Rating(user=1404, product=971880107, rating=0.0),
#  Rating(user=1405, product=971880107, rating=6.0),
#  Rating(user=1406, product=971880107, rating=0.0),
#  Rating(user=1410, product=971880107, rating=0.0),
#  Rating(user=1414, product=971880107, rating=0.0),
#  Rating(user=1416, product=971880107, rating=0.0),
#  Rating(user=1418, product=971880107, rating=0.0),
#  Rating(user=1420, product=971880107, rating=0.0),
#  Rating(user=1420, product=971880107, rating=0.0),
#  Rating(user=1422, product=971880107, rating=0.0),
#  Rating(user=1425, product=971880107, rating=0.0),
#  Rating(user=1426, product=971880107, rating=1.0),
#  Rating(user=1430, product=971880107, rating=0.0),
#  Rating(user=1432, product=971880107, rating=0.0),
#  Rating(user=1434, product=971880107, rating=0.0),
#  Rating(user=1439, product=971880107, rating=0.0),
#  Rating(user=1449, product=971880107, rating=0.0),
#  Rating(user=1456, product=971880107, rating=0.0),
#  Rating(user=1456, product=971880107, rating=0.0),
#  Rating(user=1458, product=971880107, rating=0.0),
#  Rating(user=1459, product=971880107, rating=0.0),
#  Rating(user=1461, product=971880107, rating=0.0),
#  Rating(user=1463, product=971880107, rating=0.0),
#  Rating(user=1464, product=971880107, rating=0.0),
#  Rating(user=1466, product=971880107, rating=0.0),
#  Rating(user=1466, product=971880107, rating=0.0),
#  Rating(user=1474, product=971880107, rating=0.0),
#  Rating(user=1476, product=971880107, rating=0.0),
#  Rating(user=1479, product=971880107, rating=4.0),
#  Rating(user=1479, product=971880107, rating=0.0),
#  Rating(user=1481, product=971880107, rating=5.0),
#  Rating(user=1483, product=971880107, rating=0.0),
#  Rating(user=1491, product=971880107, rating=0.0),
#  Rating(user=1500, product=971880107, rating=0.0),
#  Rating(user=1501, product=971880107, rating=0.0),
#  Rating(user=1509, product=971880107, rating=0.0),
#  Rating(user=1514, product=971880107, rating=0.0),
#  Rating(user=1527, product=971880107, rating=0.0),
#  Rating(user=1529, product=971880107, rating=0.0),
#  Rating(user=1529, product=971880107, rating=0.0),
#  Rating(user=1531, product=971880107, rating=0.0),
#  Rating(user=1536, product=971880107, rating=0.0),
#  Rating(user=1537, product=971880107, rating=0.0),
#  Rating(user=1544, product=971880107, rating=0.0),
#  Rating(user=1544, product=971880107, rating=0.0),
#  Rating(user=1551, product=971880107, rating=0.0),
#  Rating(user=1565, product=971880107, rating=0.0),
#  Rating(user=1567, product=971880107, rating=0.0),
#  Rating(user=1568, product=971880107, rating=0.0),
#  Rating(user=1569, product=971880107, rating=0.0),
#  Rating(user=1571, product=971880107, rating=0.0),
#  Rating(user=1576, product=971880107, rating=2.0),
#  Rating(user=1586, product=971880107, rating=7.0),
#  Rating(user=1590, product=971880107, rating=0.0),
#  Rating(user=1595, product=971880107, rating=2.0),
#  Rating(user=1606, product=971880107, rating=6.0),
#  Rating(user=1607, product=971880107, rating=0.0),
#  Rating(user=1610, product=971880107, rating=0.0),
#  Rating(user=1617, product=971880107, rating=2.0),
#  Rating(user=1619, product=971880107, rating=0.0),
#  Rating(user=1620, product=971880107, rating=0.0),
#  Rating(user=1620, product=971880107, rating=0.0),
#  Rating(user=1622, product=971880107, rating=0.0),
#  Rating(user=1625, product=971880107, rating=10.0),
#  Rating(user=1627, product=971880107, rating=0.0),
#  Rating(user=1643, product=971880107, rating=6.0),
#  Rating(user=1646, product=971880107, rating=0.0),
#  Rating(user=1649, product=971880107, rating=0.0),
#  Rating(user=1649, product=971880107, rating=0.0),
#  Rating(user=1655, product=971880107, rating=0.0),
#  Rating(user=1655, product=971880107, rating=0.0),
#  Rating(user=1666, product=971880107, rating=0.0),
#  Rating(user=1667, product=971880107, rating=0.0),
#  Rating(user=1669, product=971880107, rating=0.0),
#  Rating(user=1671, product=971880107, rating=0.0),
#  Rating(user=1674, product=971880107, rating=0.0),
#  Rating(user=1688, product=971880107, rating=0.0),
#  Rating(user=1702, product=971880107, rating=0.0),
#  Rating(user=1704, product=971880107, rating=0.0),
#  Rating(user=1705, product=971880107, rating=0.0),
#  Rating(user=1705, product=971880107, rating=0.0),
#  Rating(user=1706, product=971880107, rating=0.0),
#  Rating(user=1708, product=971880107, rating=0.0),
#  Rating(user=1711, product=971880107, rating=0.0),
#  Rating(user=1722, product=971880107, rating=0.0),
#  Rating(user=1725, product=971880107, rating=0.0),
#  Rating(user=1726, product=971880107, rating=0.0),
#  Rating(user=1727, product=971880107, rating=0.0),
#  Rating(user=1734, product=971880107, rating=0.0),
#  Rating(user=1736, product=971880107, rating=0.0),
#  Rating(user=1740, product=971880107, rating=0.0),
#  Rating(user=1741, product=971880107, rating=0.0),
#  Rating(user=1743, product=971880107, rating=0.0),
#  Rating(user=1758, product=971880107, rating=0.0),
#  Rating(user=1760, product=971880107, rating=3.0),
#  Rating(user=1760, product=971880107, rating=0.0),
#  Rating(user=1765, product=971880107, rating=0.0),
#  Rating(user=1770, product=971880107, rating=0.0),
#  Rating(user=1772, product=971880107, rating=0.0),
#  Rating(user=1772, product=971880107, rating=0.0),
#  Rating(user=1774, product=971880107, rating=0.0),
#  Rating(user=1775, product=971880107, rating=0.0),
#  Rating(user=1779, product=971880107, rating=0.0),
#  Rating(user=1789, product=971880107, rating=0.0),
#  Rating(user=1794, product=971880107, rating=4.0),
#  Rating(user=1797, product=971880107, rating=0.0),
#  Rating(user=1801, product=971880107, rating=5.0),
#  Rating(user=1803, product=971880107, rating=0.0),
#  Rating(user=1804, product=971880107, rating=0.0),
#  Rating(user=1804, product=971880107, rating=3.0),
#  Rating(user=1809, product=971880107, rating=0.0),
#  Rating(user=1811, product=971880107, rating=0.0),
#  Rating(user=1823, product=971880107, rating=0.0),
#  Rating(user=1823, product=971880107, rating=0.0),
#  Rating(user=1824, product=971880107, rating=0.0),
#  Rating(user=1825, product=971880107, rating=0.0),
#  Rating(user=1827, product=971880107, rating=0.0),
#  Rating(user=1827, product=971880107, rating=0.0),
#  Rating(user=1828, product=971880107, rating=0.0),
#  Rating(user=1834, product=971880107, rating=0.0),
#  Rating(user=1835, product=971880107, rating=0.0),
#  Rating(user=1837, product=971880107, rating=0.0),
#  Rating(user=1851, product=971880107, rating=0.0),
#  Rating(user=1853, product=971880107, rating=0.0),
#  Rating(user=1856, product=971880107, rating=0.0),
#  Rating(user=1859, product=971880107, rating=0.0),
#  Rating(user=1872, product=971880107, rating=7.0),
#  Rating(user=1873, product=971880107, rating=0.0),
#  Rating(user=1877, product=971880107, rating=0.0),
#  Rating(user=1877, product=971880107, rating=8.0),
#  Rating(user=1881, product=971880107, rating=0.0),
#  Rating(user=1882, product=971880107, rating=0.0),
#  Rating(user=1883, product=971880107, rating=5.0),
#  Rating(user=1884, product=971880107, rating=1.0),
#  Rating(user=1893, product=971880107, rating=0.0),
#  Rating(user=1895, product=971880107, rating=0.0),
#  Rating(user=1907, product=971880107, rating=0.0),
#  Rating(user=1931, product=971880107, rating=0.0),
#  Rating(user=1936, product=971880107, rating=0.0),
#  Rating(user=1937, product=971880107, rating=0.0),
#  Rating(user=1937, product=971880107, rating=2.0),
#  Rating(user=1939, product=971880107, rating=0.0),
#  Rating(user=1944, product=971880107, rating=0.0),
#  Rating(user=1947, product=971880107, rating=2.0),
#  Rating(user=1951, product=971880107, rating=0.0),
#  Rating(user=1957, product=971880107, rating=0.0),
#  Rating(user=1964, product=971880107, rating=0.0),
#  Rating(user=1969, product=971880107, rating=0.0),
#  Rating(user=1975, product=971880107, rating=5.0),
#  Rating(user=1998, product=971880107, rating=0.0),
#  Rating(user=2002, product=971880107, rating=0.0),
#  Rating(user=2014, product=971880107, rating=3.0),
#  Rating(user=2020, product=971880107, rating=0.0),
#  Rating(user=2021, product=971880107, rating=0.0),
#  Rating(user=2027, product=971880107, rating=0.0),
#  Rating(user=2030, product=971880107, rating=2.0),
#  Rating(user=2050, product=971880107, rating=0.0),
#  Rating(user=2055, product=971880107, rating=0.0),
#  Rating(user=2059, product=971880107, rating=0.0),
#  Rating(user=2069, product=971880107, rating=0.0),
#  Rating(user=2073, product=971880107, rating=0.0),
#  Rating(user=2074, product=971880107, rating=0.0),
#  Rating(user=2078, product=971880107, rating=0.0),
#  Rating(user=2084, product=971880107, rating=4.0),
#  Rating(user=2084, product=971880107, rating=8.0),
#  Rating(user=2088, product=971880107, rating=0.0),
#  Rating(user=2088, product=971880107, rating=0.0),
#  Rating(user=2093, product=971880107, rating=0.0),
#  Rating(user=2094, product=971880107, rating=0.0),
#  Rating(user=2095, product=971880107, rating=0.0),
#  Rating(user=2095, product=971880107, rating=4.0),
#  Rating(user=2097, product=971880107, rating=0.0),
#  Rating(user=2104, product=971880107, rating=0.0),
#  Rating(user=2105, product=971880107, rating=0.0),
#  Rating(user=2106, product=971880107, rating=3.0),
#  Rating(user=2109, product=971880107, rating=0.0),
#  Rating(user=2114, product=971880107, rating=0.0),
#  Rating(user=2114, product=971880107, rating=0.0),
#  Rating(user=2119, product=971880107, rating=0.0),
#  Rating(user=2125, product=971880107, rating=0.0),
#  Rating(user=2132, product=971880107, rating=0.0),
#  Rating(user=2133, product=971880107, rating=0.0),
#  Rating(user=2133, product=971880107, rating=0.0),
#  Rating(user=2134, product=971880107, rating=0.0),
#  Rating(user=2139, product=971880107, rating=0.0),
#  Rating(user=2161, product=971880107, rating=0.0),
#  Rating(user=2162, product=971880107, rating=5.0),
#  Rating(user=2166, product=971880107, rating=0.0),
#  Rating(user=2171, product=971880107, rating=0.0),
#  Rating(user=2173, product=971880107, rating=0.0),
#  Rating(user=2180, product=971880107, rating=0.0),
#  Rating(user=2188, product=971880107, rating=0.0),
#  Rating(user=2190, product=971880107, rating=0.0),
#  Rating(user=2191, product=971880107, rating=3.0),
#  Rating(user=2195, product=971880107, rating=0.0),
#  Rating(user=2196, product=971880107, rating=0.0),
#  Rating(user=2196, product=971880107, rating=0.0),
#  Rating(user=2198, product=971880107, rating=1.0),
#  Rating(user=2199, product=971880107, rating=3.0),
#  Rating(user=2202, product=971880107, rating=0.0),
#  Rating(user=2204, product=971880107, rating=0.0),
#  Rating(user=2206, product=971880107, rating=3.0),
#  Rating(user=2211, product=971880107, rating=0.0),
#  Rating(user=2215, product=971880107, rating=8.0),
#  Rating(user=2215, product=971880107, rating=10.0),
#  Rating(user=2232, product=971880107, rating=0.0),
#  Rating(user=2238, product=971880107, rating=0.0),
#  Rating(user=2239, product=971880107, rating=5.0),
#  Rating(user=2239, product=971880107, rating=0.0),
#  Rating(user=2242, product=971880107, rating=0.0),
#  Rating(user=2247, product=971880107, rating=0.0),
#  Rating(user=2250, product=971880107, rating=0.0),
#  Rating(user=2255, product=971880107, rating=3.0),
#  Rating(user=2256, product=971880107, rating=0.0),
#  Rating(user=2260, product=971880107, rating=7.0),
#  Rating(user=2260, product=971880107, rating=0.0),
#  Rating(user=2275, product=971880107, rating=0.0),
#  Rating(user=2286, product=971880107, rating=0.0),
#  Rating(user=2287, product=971880107, rating=0.0),
#  Rating(user=2295, product=971880107, rating=0.0),
#  Rating(user=2295, product=971880107, rating=0.0),
#  Rating(user=2296, product=971880107, rating=1.0),
#  Rating(user=2297, product=971880107, rating=0.0),
#  Rating(user=2300, product=971880107, rating=6.0),
#  Rating(user=2300, product=971880107, rating=0.0),
#  Rating(user=2300, product=971880107, rating=0.0),
#  Rating(user=2302, product=971880107, rating=0.0),
#  Rating(user=2304, product=971880107, rating=0.0),
#  Rating(user=2304, product=971880107, rating=1.0),
#  Rating(user=2305, product=971880107, rating=3.0),
#  Rating(user=2308, product=971880107, rating=0.0),
#  Rating(user=2311, product=971880107, rating=5.0),
#  Rating(user=2314, product=971880107, rating=0.0),
#  Rating(user=2317, product=971880107, rating=0.0),
#  Rating(user=2318, product=971880107, rating=0.0),
#  Rating(user=2321, product=971880107, rating=0.0),
#  Rating(user=2328, product=971880107, rating=0.0),
#  Rating(user=2335, product=971880107, rating=0.0),
#  Rating(user=2337, product=971880107, rating=0.0),
#  Rating(user=2345, product=971880107, rating=0.0),
#  Rating(user=2347, product=971880107, rating=0.0),
#  Rating(user=2347, product=971880107, rating=4.0),
#  Rating(user=2353, product=971880107, rating=0.0),
#  Rating(user=2355, product=971880107, rating=4.0),
#  Rating(user=2356, product=971880107, rating=1.0),
#  Rating(user=2359, product=971880107, rating=0.0),
#  Rating(user=2359, product=971880107, rating=0.0),
#  Rating(user=2372, product=971880107, rating=5.0),
#  Rating(user=2372, product=971880107, rating=7.0),
#  Rating(user=2390, product=971880107, rating=0.0),
#  Rating(user=2391, product=971880107, rating=5.0),
#  Rating(user=2394, product=971880107, rating=0.0),
#  Rating(user=2394, product=971880107, rating=0.0),
#  Rating(user=2398, product=971880107, rating=7.0),
#  Rating(user=2400, product=971880107, rating=0.0),
#  Rating(user=2404, product=971880107, rating=0.0),
#  Rating(user=2405, product=971880107, rating=0.0),
#  Rating(user=2410, product=971880107, rating=0.0),
#  Rating(user=2414, product=971880107, rating=1.0),
#  Rating(user=2419, product=971880107, rating=0.0),
#  Rating(user=2422, product=971880107, rating=3.0),
#  Rating(user=2422, product=971880107, rating=0.0),
#  Rating(user=2428, product=971880107, rating=0.0),
#  Rating(user=2429, product=971880107, rating=0.0),
#  Rating(user=2430, product=971880107, rating=8.0),
#  Rating(user=2437, product=971880107, rating=0.0),
#  Rating(user=2438, product=971880107, rating=0.0),
#  Rating(user=2439, product=971880107, rating=0.0),
#  Rating(user=2444, product=971880107, rating=3.0),
#  Rating(user=2446, product=971880107, rating=0.0),
#  Rating(user=2448, product=971880107, rating=5.0),
#  Rating(user=2449, product=971880107, rating=1.0),
#  Rating(user=2454, product=971880107, rating=0.0),
#  Rating(user=2455, product=971880107, rating=7.0),
#  Rating(user=2456, product=971880107, rating=0.0),
#  Rating(user=2458, product=971880107, rating=0.0),
#  Rating(user=2459, product=971880107, rating=0.0),
#  Rating(user=2466, product=971880107, rating=0.0),
#  Rating(user=2466, product=971880107, rating=0.0),
#  Rating(user=2466, product=971880107, rating=6.0),
#  Rating(user=2470, product=971880107, rating=0.0),
#  Rating(user=2475, product=971880107, rating=0.0),
#  Rating(user=2487, product=971880107, rating=4.0),
#  Rating(user=2487, product=971880107, rating=0.0),
#  Rating(user=2494, product=971880107, rating=0.0),
#  Rating(user=2499, product=971880107, rating=4.0),
#  Rating(user=2499, product=971880107, rating=0.0),
#  Rating(user=2501, product=971880107, rating=7.0),
#  Rating(user=2507, product=971880107, rating=0.0),
#  Rating(user=2511, product=971880107, rating=0.0),
#  Rating(user=2514, product=971880107, rating=1.0),
#  Rating(user=2515, product=971880107, rating=0.0),
#  Rating(user=2518, product=971880107, rating=0.0),
#  Rating(user=2519, product=971880107, rating=0.0),
#  Rating(user=2522, product=971880107, rating=0.0),
#  Rating(user=2523, product=971880107, rating=0.0),
#  Rating(user=2536, product=971880107, rating=0.0),
#  Rating(user=2540, product=971880107, rating=0.0),
#  Rating(user=2542, product=971880107, rating=0.0),
#  Rating(user=2544, product=971880107, rating=0.0),
#  Rating(user=2552, product=971880107, rating=0.0),
#  Rating(user=2557, product=971880107, rating=0.0),
#  Rating(user=2565, product=971880107, rating=2.0),
#  Rating(user=2570, product=971880107, rating=3.0),
#  Rating(user=2572, product=971880107, rating=0.0),
#  Rating(user=2581, product=971880107, rating=0.0),
#  Rating(user=2581, product=971880107, rating=3.0),
#  Rating(user=2586, product=971880107, rating=1.0),
#  Rating(user=2590, product=971880107, rating=0.0),
#  Rating(user=2590, product=971880107, rating=0.0),
#  Rating(user=2591, product=971880107, rating=0.0),
#  Rating(user=2591, product=971880107, rating=3.0),
#  Rating(user=2592, product=971880107, rating=0.0),
#  Rating(user=2593, product=971880107, rating=0.0),
#  Rating(user=2599, product=971880107, rating=0.0),
#  Rating(user=2601, product=971880107, rating=0.0),
#  Rating(user=2602, product=971880107, rating=5.0),
#  Rating(user=2613, product=971880107, rating=0.0),
#  Rating(user=2615, product=971880107, rating=0.0),
#  Rating(user=2617, product=971880107, rating=0.0),
#  Rating(user=2618, product=971880107, rating=0.0),
#  Rating(user=2623, product=971880107, rating=0.0),
#  Rating(user=2624, product=971880107, rating=0.0),
#  Rating(user=2629, product=971880107, rating=0.0),
#  Rating(user=2630, product=971880107, rating=2.0),
#  Rating(user=2631, product=971880107, rating=0.0),
#  Rating(user=2632, product=971880107, rating=1.0),
#  Rating(user=2641, product=971880107, rating=0.0),
#  Rating(user=2642, product=971880107, rating=0.0),
#  Rating(user=2643, product=971880107, rating=0.0),
#  Rating(user=2643, product=971880107, rating=0.0),
#  Rating(user=2645, product=971880107, rating=0.0),
#  Rating(user=2646, product=971880107, rating=2.0),
#  Rating(user=2651, product=971880107, rating=0.0),
#  Rating(user=2654, product=971880107, rating=0.0),
#  Rating(user=2659, product=971880107, rating=4.0),
#  Rating(user=2660, product=971880107, rating=0.0),
#  Rating(user=2668, product=971880107, rating=0.0),
#  Rating(user=2679, product=971880107, rating=0.0),
#  Rating(user=2683, product=971880107, rating=0.0),
#  Rating(user=2685, product=971880107, rating=0.0),
#  Rating(user=2693, product=971880107, rating=1.0),
#  Rating(user=2693, product=971880107, rating=5.0),
#  Rating(user=2693, product=971880107, rating=0.0),
#  Rating(user=2698, product=971880107, rating=0.0),
#  Rating(user=2708, product=971880107, rating=0.0),
#  Rating(user=2713, product=971880107, rating=5.0),
#  Rating(user=2715, product=971880107, rating=0.0),
#  Rating(user=2715, product=971880107, rating=0.0),
#  Rating(user=2720, product=971880107, rating=0.0),
#  Rating(user=2723, product=971880107, rating=0.0),
#  Rating(user=2737, product=971880107, rating=0.0),
#  Rating(user=2737, product=971880107, rating=0.0),
#  Rating(user=2742, product=971880107, rating=0.0),
#  Rating(user=2748, product=971880107, rating=0.0),
#  Rating(user=2753, product=971880107, rating=0.0),
#  Rating(user=2754, product=971880107, rating=0.0),
#  Rating(user=2756, product=971880107, rating=0.0),
#  Rating(user=2761, product=971880107, rating=0.0),
#  Rating(user=2770, product=971880107, rating=2.0),
#  Rating(user=2773, product=971880107, rating=0.0),
#  Rating(user=2775, product=971880107, rating=0.0),
#  Rating(user=2779, product=971880107, rating=0.0),
#  Rating(user=6007, product=345402871, rating=0.0),
#  Rating(user=1256, product=345402871, rating=0.0),
#  Rating(user=1358, product=345402871, rating=0.0),
#  Rating(user=1476, product=345402871, rating=0.0),
#  Rating(user=1679, product=345402871, rating=0.0),
#  Rating(user=1901, product=345402871, rating=9.0),
#  Rating(user=2040, product=345402871, rating=0.0),
#  Rating(user=2246, product=345402871, rating=6.0),
#  Rating(user=2822, product=345402871, rating=7.0),
#  Rating(user=5214, product=345402871, rating=6.0),
#  Rating(user=5432, product=345402871, rating=0.0),
#  Rating(user=6227, product=345402871, rating=0.0),
#  Rating(user=6288, product=345402871, rating=0.0),
#  Rating(user=6329, product=345402871, rating=0.0),
#  Rating(user=6904, product=345402871, rating=0.0),
#  Rating(user=8668, product=345402871, rating=6.0),
#  Rating(user=8902, product=345402871, rating=8.0),
#  Rating(user=9943, product=345402871, rating=0.0),
#  Rating(user=1006, product=345402871, rating=8.0),
#  Rating(user=1029, product=345402871, rating=0.0),
#  Rating(user=1050, product=345402871, rating=0.0),
#  Rating(user=1054, product=345402871, rating=6.0),
#  Rating(user=1056, product=345402871, rating=0.0),
#  Rating(user=1072, product=345402871, rating=8.0),
#  Rating(user=1083, product=345402871, rating=0.0),
#  Rating(user=1097, product=345402871, rating=0.0),
#  Rating(user=1175, product=345402871, rating=3.0),
#  Rating(user=1185, product=345402871, rating=0.0),
#  Rating(user=1249, product=345402871, rating=0.0),
#  Rating(user=1282, product=345402871, rating=0.0),
#  Rating(user=1353, product=345402871, rating=8.0),
#  Rating(user=1364, product=345402871, rating=0.0),
#  Rating(user=1418, product=345402871, rating=0.0),
#  Rating(user=1462, product=345402871, rating=0.0),
#  Rating(user=1498, product=345402871, rating=9.0),
#  Rating(user=1517, product=345402871, rating=0.0),
#  Rating(user=1532, product=345402871, rating=8.0),
#  Rating(user=1585, product=345402871, rating=0.0),
#  Rating(user=1617, product=345402871, rating=9.0),
#  Rating(user=1741, product=345402871, rating=0.0),
#  Rating(user=1747, product=345402871, rating=8.0),
#  Rating(user=1803, product=345402871, rating=7.0),
#  Rating(user=1824, product=345402871, rating=0.0),
#  Rating(user=1865, product=345402871, rating=0.0),
#  Rating(user=1890, product=345402871, rating=0.0),
#  Rating(user=1987, product=345402871, rating=0.0),
#  Rating(user=1994, product=345402871, rating=0.0),
#  Rating(user=2037, product=345402871, rating=10.0),
#  Rating(user=2090, product=345402871, rating=8.0),
#  Rating(user=2128, product=345402871, rating=0.0),
#  Rating(user=2173, product=345402871, rating=5.0),
#  Rating(user=2200, product=345402871, rating=0.0),
#  Rating(user=2230, product=345402871, rating=0.0),
#  Rating(user=2312, product=345402871, rating=0.0),
#  Rating(user=2312, product=345402871, rating=0.0),
#  Rating(user=2327, product=345402871, rating=10.0),
#  Rating(user=2330, product=345402871, rating=5.0),
#  Rating(user=2346, product=345402871, rating=4.0),
#  Rating(user=2415, product=345402871, rating=0.0),
#  Rating(user=2421, product=345402871, rating=0.0),
#  Rating(user=2432, product=345402871, rating=8.0),
#  Rating(user=2485, product=345402871, rating=7.0),
#  Rating(user=2551, product=345402871, rating=8.0),
#  Rating(user=2608, product=345402871, rating=0.0),
#  Rating(user=2635, product=345402871, rating=0.0),
#  Rating(user=2646, product=345402871, rating=5.0),
#  Rating(user=2729, product=345402871, rating=7.0),
#  Rating(user=2730, product=345402871, rating=0.0),
#  Rating(user=2779, product=345402871, rating=0.0),
#  Rating(user=1256, product=345417623, rating=7.0),
#  Rating(user=1360, product=345417623, rating=0.0),
#  Rating(user=1372, product=345417623, rating=7.0),
#  Rating(user=1858, product=345417623, rating=8.0),
#  Rating(user=2051, product=345417623, rating=0.0),
#  Rating(user=2206, product=345417623, rating=0.0),
#  Rating(user=2406, product=345417623, rating=0.0),
#  Rating(user=2414, product=345417623, rating=8.0),
#  Rating(user=2477, product=345417623, rating=10.0),
#  Rating(user=2913, product=345417623, rating=10.0),
#  Rating(user=3117, product=345417623, rating=0.0),
#  ...]

# %%
# Test verilerini alın
test_data = test_data.collect()

# Her bir test verisi için tahmin yapın ve gerçek değerlerle karşılaştırın
for row in test_data:
    user_id = row.user
    item_id = row.product
    rating = row.rating
    
    if model1.userFeatures().lookup(user_id) and model1.productFeatures().lookup(item_id):
        # Tahmin yap
        predicted_rating = model1.predict(user_id, item_id)
        
        # Gerçek değer ile karşılaştır
        print("Gerçek Değer: {}, Tahmin: {}".format(rating, predicted_rating))
# Out:
# Gerçek Değer: 8.0, Tahmin: 8.164040876630203
# Gerçek Değer: 7.0, Tahmin: 6.9893751721932595
# Gerçek Değer: 0.0, Tahmin: 0.0017406587034818344
# Gerçek Değer: 9.0, Tahmin: 8.978197785783918
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 9.0, Tahmin: 8.99896692895764
# Gerçek Değer: 9.0, Tahmin: 8.992994953015454
# Gerçek Değer: 0.0, Tahmin: -0.04792347092454463
# Gerçek Değer: 8.0, Tahmin: -5.412691931826782
# Gerçek Değer: 7.0, Tahmin: 6.903181626545695
# Gerçek Değer: 10.0, Tahmin: 9.981166871630643
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: -0
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 7.0, Tahmin: 6.998566247940248
# Gerçek Değer: 0.0, Tahmin: 0.006162813941205769
# Gerçek Değer: 8.0, Tahmin: 7.993336309078558
# Gerçek Değer: 0.0, Tahmin: -0.1639397944221166
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: 0.07965312622227927
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 5.0, Tahmin: 4.994653777880354
# Gerçek Değer: 0.0, Tahmin: -0.08727361823354052
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 5.0, Tahmin: -3.2169087330760195
# Gerçek Değer: 8.0, Tahmin: 7.994394459504054
# Gerçek Değer: 0.0, Tahmin: -0.05777130136923603
# Gerçek Değer: 10.0, Tahmin: 12.656916596385758
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 10.0, Tahmin: 9.996515159907382
# Gerçek Değer: 8.0, Tahmin: 7.993346591581431
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: 0.03411281043422587
# Gerçek Değer: 0.0, Tahmin: 0.10259963184225462
# Gerçek Değer: 9.0, Tahmin: 8.996863448262172
# Gerçek Değer: 9.0, Tahmin: 8.651325200691858
# Gerçek Değer: 0.0, Tahmin: -1.427144720947533
# Gerçek Değer: 5.0, Tahmin: 4.723373419984174
# Gerçek Değer: 10.0, Tahmin: 0.23389918533311516
# Gerçek Değer: 10.0, Tahmin: 9.988834883007577
# Gerçek Değer: 8.0, Tahmin: 3.76624119000763
# Gerçek Değer: 10.0, Tahmin: 9.98401325002422
# Gerçek Değer: 8.0, Tahmin: 7.968584126364826
# Gerçek Değer: 3.0, Tahmin: -3.1110917945046292
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: -0.4008591265517758
# Gerçek Değer: 10.0, Tahmin: 9.949076571616208
# Gerçek Değer: 0.0, Tahmin: -0.7631219277408645
# Gerçek Değer: 0.0, Tahmin: -0.10911122472263912
# Gerçek Değer: 10.0, Tahmin: 9.891466476788533
# Gerçek Değer: 9.0, Tahmin: 8.99384349952498
# Gerçek Değer: 0.0, Tahmin: -0.5855959996003488
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: -0.07913292691471696
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: 0.10666514475647837
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 0.0, Tahmin: -0.001076085602135457
# Gerçek Değer: 10.0, Tahmin: 9.990720102647355
# Gerçek Değer: 0.0, Tahmin: 0.0
# Gerçek Değer: 10.0, Tahmin: 9.995723179961205
# Gerçek Değer: 7.0, Tahmin: 6.9825532624181825
# Gerçek Değer: 8.0, Tahmin: 7.864256075032344
# Gerçek Değer: 10.0, Tahmin: -6.756079739917981
# Gerçek Değer: 0.0, Tahmin: 0.2548858128097642
# Gerçek Değer: 0.0, Tahmin: -2.564833610844449
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [100], line 10
#       7 item_id = row.product
#       8 rating = row.rating
# ---> 10 if model1.userFeatures().lookup(user_id) and model1.productFeatures().lookup(item_id):
#      11     # Tahmin yap
#      12     predicted_rating = model1.predict(user_id, item_id)
#      14     # Gerçek değer ile karşılaştır
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pyspark/rdd.py:4886, in RDD.lookup(self, key)
#    4883 if self.partitioner is not None:
#    4884     return self.ctx.runJob(values, lambda x: x, [self.partitioner(key)])
# -> 4886 return values.collect()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pyspark/rdd.py:1814, in RDD.collect(self)
#    1812 with SCCallSiteSync(self.context):
#    1813     assert self.ctx._jvm is not None
# -> 1814     sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#    1815 return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def cosinesimilarity(item_id, a, b):
    dot = np. dot (a, b)
    norma = np.linalg.norm(a)
    normb = np.linalg.norm(b)
    cos = dot / (norma * normb)
    return item_id, cos

# %%
item id = 567
item_vector = model.productFeatures ().lookup(item_id)[0]

# %%
cosineSimilarity(item_id, item_vector, item_vector)
